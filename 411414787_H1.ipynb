# %% [markdown]
# <a href="https://colab.research.google.com/github/yuhanc07-prog/115-1/blob/main/411414787_H1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello\nhello")
# Out:
# hello
# hello

# %%
print("2026","09","22",sep="/")
# Out:
# 2026/09/22

# %%
a=5
b=2.5
c="python"
print(type(c))
# Out:
# <class 'str'>

# %%
x=20
y=30
temp=x
x=y
y=temp
print(x,y)
# Out:
# 30 20

# %%
t=5
h=5
print(id(t))
# Out:
# 10446536

# %%
a=50000
b=0.015
c=5
total=a*((1+b)**c)
print(total)
# Out:
# 53864.20019421873
