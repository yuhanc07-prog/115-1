# %% [markdown]
# <a href="https://colab.research.google.com/github/yuhanc07-prog/115-1/blob/main/4114147987_H2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=11
b=12
print("{1}\n{0}".format(a,b))
# Out:
# 12
# 11

# %%
a=11
b=12
print("{e}\n{f}".format(e=a,f=b))
# Out:
# 11
# 12

# %%
a=11.123456
print("{:.2f}".format(a))
# Out:
# 11.12

# %%
a=11.123456
print("{0}".format(a))
print(f"{a}")
# Out:
# 11.123456
# 11.123456

# %%
a=180
print(f"{0:10}")
# Out:
#          0

# %%
x=input("請輸入數字:")
print(x)
# Out:
# 請輸入數字:67
# 67

# %%
x=float(input("請輸入數字:"))
print(type(x))
# Out:
# 請輸入數字:67.6767
# <class 'float'>

# %%
x=int(input("請輸入目前金幣數量:"))
y=int(input("請輸入獲得金幣數量:"))
total=x+y
print(f"任務完成！你現在有{total}枚金幣")
# Out:
# 請輸入目前金幣數量:500
# 請輸入獲得金幣數量:250
# 任務完成！你現在有750枚金幣
